# %%
from stellargraph import StellarGraph
import pandas as pd

# %%
# Nodes
train = pd.read_csv('../data/split/train_set_subset.csv', low_memory=False)

validation = pd.read_csv('../data/split/validation_set_subset.csv', low_memory=False)
test = pd.read_csv('../data/split/test_set_subset.csv', low_memory=False)

# Edges
edges = pd.read_csv('../data/polimi.case.graphs.edges.csv', low_memory=False, 
                    header=None, names=["id", "source", "target", "label", "similarity", "amount"])

# Nodes for test
core_vertices = pd.read_csv('../data/training.core.vertices.csv', low_memory=False)
ext_vertices = pd.read_csv('../data/training.extended.vertices.csv', low_memory=False)

# %%
ed = edges.copy()

# %%
ed = ed.drop([0])
ed = ed.drop(['label', 'similarity', 'amount'], 1)

# %%
ed
# Out:
#                   id       source       target
# 1       400111489790      1502000   2003003713
# 2       400111390345      1502000  20030012850
# 3       350111213741      1502001  15020066888
# 4       350111280215      1502001  15020063877
# 5       400111415408      1502001  20030019012
# ...              ...          ...          ...
# 921872  650111831593  20030017545   3001182900
# 921873  650111820399  20030017545   3001184369
# 921874  650111814941  20030017545   3001147740
# 921875  650111838272  20030017545   3001163228
# 921876  650111856136  20030017545   3001149373
#
# [921876 rows x 3 columns]

# %%
nod = train.copy()

# %%
nod
# Out:
#             node_id  Label  Revenue Size Flag Account ID String  Address  \
# 0        3001167904      5                 -1           missing  missing
# 1       15020059496      1                  4        xs1WkuTym3  missing
# 2       15020026582      1                  3        ukpmdugHEs  missing
# 3        1502015926      1                  4        rrusZirsiq  missing
# 4        3001132750      5                 -1           missing  missing
# ...             ...    ...                ...               ...      ...
# 223927   2003014831      4                 -1           missing  missing
# 223928   1502004478      1                  4        5ckxg2HLVg  missing
# 223929   3001143150      5                 -1           missing  missing
# 223930  15020145184      1                  3        I8xySuN8HD  missing
# 223931  15020057227      1                  3        6dHCxJ3dbT  missing
#
#         Person or Organisation        Name  Income Size Flag  CoreCaseGraphID  \
# 0                            2  HfXhe7Zzza                -1                0
# 1                           -1     missing                -1                0
# 2                           -1     missing                -1                0
# 3                           -1     missing                -1                0
# 4                            2  AZ9HZXBCcx                -1                0
# ...                        ...         ...               ...              ...
# 223927                       2  Pda8K6njO9                -1                0
# 223928                      -1     missing                -1                0
# 223929                       1  ia6fnhceUA                -1                0
# 223930                      -1     missing                -1                0
# 223931                      -1     missing                -1                0
#
#         ExtendedCaseGraphID
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 223927                    0
# 223928                    0
# 223929                    0
# 223930                    0
# 223931                    0
#
# [223932 rows x 10 columns]

# %%
nod = nod.rename(columns={'node_id': 'id'})

# %%
nod = nod.set_index('id')

# %%
nod = nod.drop(columns=["Account ID String", 'Address', 'Name'])

# %%
#Drop all edges that are not part of the training set

# %%
test = StellarGraph({"node": nod}, {"edge": ed})
print(test.info())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/hpc_2020-u8KpsjyS/lib/python3.8/site-packages/stellargraph/core/convert.py in _node_ids_to_iloc(node_ids)
#     275         try:
# --> 276             return nodes.ids.to_iloc(node_ids, strict=True)
#     277         except KeyError as e:
#
# ~/.local/share/virtualenvs/hpc_2020-u8KpsjyS/lib/python3.8/site-packages/stellargraph/core/element_data.py in to_iloc(self, ids, smaller_type, strict)
#      96         if strict:
# ---> 97             self.require_valid(ids, internal_ids)
#      98
#
# ~/.local/share/virtualenvs/hpc_2020-u8KpsjyS/lib/python3.8/site-packages/stellargraph/core/element_data.py in require_valid(self, query_ids, ilocs)
#      78
# ---> 79             raise KeyError(missing_values)
#      80
#
# KeyError: array(['1502000', '1502000', '1502001', ..., '20030017545', '20030017545',
#        '20030017545'], dtype=object)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-215a5896a58c> in <module>
# ----> 1 test = StellarGraph({"node": nod}, {"edge": ed})
#       2 print(test.info())
#
# ~/.local/share/virtualenvs/hpc_2020-u8KpsjyS/lib/python3.8/site-packages/stellargraph/core/graph.py in __init__(self, nodes, edges, is_directed, source_column, target_column, edge_weight_column, edge_type_column, node_type_default, edge_type_default, dtype, graph, node_type_name, edge_type_name, node_features)
#     416             )
#     417
# --> 418             internal_edges = convert.convert_edges(
#     419                 edges,
#     420                 name="edges",
#
# ~/.local/share/virtualenvs/hpc_2020-u8KpsjyS/lib/python3.8/site-packages/stellargraph/core/convert.py in convert_edges(data, name, default_type, source_column, target_column, weight_column, type_column, nodes, dtype)
#     307         dtype=dtype,
#     308     )
# --> 309     ids, columns, type_info = converter.convert(data)
#     310
#     311     weight_col = columns[WEIGHT]
#
# ~/.local/share/virtualenvs/hpc_2020-u8KpsjyS/lib/python3.8/site-packages/stellargraph/core/convert.py in convert(self, elements)
#     233             )
#     234
# --> 235         singles = {
#     236             type_name: self._convert_single(type_name, data)
#     237             for type_name, data in elements.items()
#
# ~/.local/share/virtualenvs/hpc_2020-u8KpsjyS/lib/python3.8/site-packages/stellargraph/core/convert.py in <dictcomp>(.0)
#     234
#     235         singles = {
# --> 236             type_name: self._convert_single(type_name, data)
#     237             for type_name, data in elements.items()
#     238         }
#
# ~/.local/share/virtualenvs/hpc_2020-u8KpsjyS/lib/python3.8/site-packages/stellargraph/core/convert.py in _convert_single(self, type_name, data)
#      80     def _convert_single(self, type_name, data):
#      81         if isinstance(data, pd.DataFrame):
# ---> 82             return self._convert_pandas(type_name, data)
#      83         elif isinstance(data, (IndexedArray, np.ndarray)):
#      84             return self._convert_rowframe(type_name, data)
#
# ~/.local/share/virtualenvs/hpc_2020-u8KpsjyS/lib/python3.8/site-packages/stellargraph/core/convert.py in _convert_pandas(self, type_name, data)
#     113             return column
#     114
# --> 115         columns = {
#     116             new_name: select_column(old_name)
#     117             for old_name, new_name in self.selected_columns.items()
#
# ~/.local/share/virtualenvs/hpc_2020-u8KpsjyS/lib/python3.8/site-packages/stellargraph/core/convert.py in <dictcomp>(.0)
#     114
#     115         columns = {
# --> 116             new_name: select_column(old_name)
#     117             for old_name, new_name in self.selected_columns.items()
#     118         }
#
# ~/.local/share/virtualenvs/hpc_2020-u8KpsjyS/lib/python3.8/site-packages/stellargraph/core/convert.py in select_column(old_name)
#     109             transform = self.transform_columns.get(old_name)
#     110             if transform is not None:
# --> 111                 column = transform(column)
#     112
#     113             return column
#
# ~/.local/share/virtualenvs/hpc_2020-u8KpsjyS/lib/python3.8/site-packages/stellargraph/core/convert.py in _node_ids_to_iloc(node_ids)
#     281             missing_values = pd.unique(missing_values)
#     282
# --> 283             raise ValueError(
#     284                 f"edges: expected all source and target node IDs to be contained in `nodes`, "
#     285                 f"found some missing: {comma_sep(missing_values)}"
#
# ValueError: edges: expected all source and target node IDs to be contained in `nodes`, found some missing: '1502000', '1502001', '1502002', '1502003', '1502004', '1502005', '1502006', '1502007', '1502008', '1502009', '15020010', '15020011', '15020012', '15020013', '15020014', '15020015', '15020016', '15020017', '15020018', '15020019', ... (170930 more)
